# %%
#ANS1:-
#Flask framework in python provides libraries and modules to build web application. It's easy to understand
# It is very flexible. It is lightweight to enable to transit into a web framework easily with some extension.

# %%
#Ans2:-
#from flask import Flask

#app = Flask(__name__)

#@app.route("/")
#def Hello_World():
    #return "Hello World"

#if __name__=="__main__":
    #app.run(host="0.0.0.0")

# %%
#Ans.3:-
# App routing in flask is used to bind url to a function. On above example url '/' is bound to
# Hello_world() function. Output of Hello_world() will be rendered to the browser.

# %% [markdown]
# Ans:4:-
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ans:5-
# ![image.png](attachment:image.png)
